# %%
# !nvidia-smi
# Out:
# Thu May  9 01:00:26 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 551.78                 Driver Version: 551.78         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   60C    P0             20W /   75W |       0MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %pip install ultralytics

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.11  Python-3.11.9 torch-2.3.0+cpu CPU (AMD Ryzen 9 5900HS with Radeon Graphics)
# Setup complete  (16 CPUs, 15.4 GB RAM, 424.9/630.0 GB disk)

# %%
from ultralytics import YOLO
# !yolo detect train source=mydrive/data_custom.yaml model=yolov8m.pt epochs=80 imgsz=640 project=mydrive/results device=0
# Out:
# WARNING ⚠️ 'data' argument is missing. Using default 'data=coco8.yaml'.
# Ultralytics YOLOv8.2.11 🚀 Python-3.11.9 torch-2.3.0+cpu
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\abira\Desktop\CleanCam-main\CleanCam-main\myenv\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\abira\Desktop\CleanCam-main\CleanCam-main\myenv\Lib\site-packages\ultralytics\cfg\__init__.py", line 583, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\abira\Desktop\CleanCam-main\CleanCam-main\myenv\Lib\site-packages\ultralytics\engine\model.py", line 654, in train
#     self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !yolo detect predict model = /mydrive/results/train/weights/best.pt source = /content/drive/MyDrive/VideoToPhoto/VID_20230506_153321[1].mp4 save = True
# !yolo detect predict model = mydrive/results/train/weights/best.pt source = mydrive/val/images/IMG355179.jpg save = True
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.11.9 torch-2.3.0+cpu CPU (AMD Ryzen 9 5900HS with Radeon Graphics)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 c:\Users\abira\Desktop\DumpDetect\DumpDetect\mydrive\val\images\IMG355179.jpg: 384x640 2 humans, 1 thrownwaste, 1 carryload, 132.2ms
# Speed: 1.5ms preprocess, 132.2ms inference, 2689.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
